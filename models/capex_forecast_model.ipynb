# %% [markdown]
# # CapEx Forecast Model
#
# This notebook loads `data/sample_capex_input.xlsx` and performs basic exploration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# Load CapEx input data
df = pd.read_excel('../data/sample_capex_input.xlsx')
df.head()

# %%
# Basic sanity checks
df.info()

# %%
# Compute total CapEx by scenario
df['Total_Cost_USD'] = df['Quantity'] * df['Unit_Cost_USD']
df.groupby('Scenario')['Total_Cost_USD'].sum()

# %%
# Plot total spend by scenario
totals = df.groupby('Scenario')['Total_Cost_USD'].sum().sort_values()
totals.plot(kind='bar')
plt.ylabel('Total CapEx (USD)')
plt.title('Total CapEx by Scenario')
plt.tight_layout()
plt.show()
